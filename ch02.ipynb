# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.naver.com"

# 요청 url 변수에 담긴 url의 html 문서를 출력한다.
req = requests.get(url)
print(req.status_code)
# Out:
# 200

# %%
# 연합뉴스 뉴스 제목 타이틀 가져오기
import requests
from bs4 import BeautifulSoup

def crawler(soup):
    # print(soup) # 여기까지 전달 잘됨
    div = soup.find("div", class_ = "list_body")

    result = []
    for a in div.find_all("a"): # find_all 반환값 형태는 리스트다! 
        result.append(a.get_text())
    
    
    return result

def main():

    # 요청 url 변수에 담긴 url의 html 문서를 출력한다. 
    custom_header = {
        'referer' : 'https://www.naver.com/',
        'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'
    }
    
    url = "https://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y"
    req = requests.get(url, headers = custom_header)
    soup = BeautifulSoup(req.text, "html.parser")
    result = crawler(soup)
    print(result)

if __name__ == "__main__":
    main()
# Out:
# <a href="https://n.news.naver.com/mnews/article/001/0014112278?sid=000000"><img alt="대전 시내 고등학교 침입해 교사 찌르고 도주한 20대 남성 체포" height="90" src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14112278.jpg?type=nf175_110" width="132"/>
# <span class="trans_border"></span></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112278?rc=N&amp;ntype=RANKING">대전 시내 고등학교 침입해 교사 찌르고 도주한 20대 남성 체포</a>
# <a class="nclicks(fls.list)" href="https://n.news.naver.com/mnews/article/001/0014112212?rc=N&amp;ntype=RANKING">학교서 교사 흉기 피습 충격…"학교 안전 시스템 어디에"</a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112159?rc=N&amp;ntype=RANKING"><strong>강남고속터미널서 흉기소지 20대 체포…피해 없어</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112257?rc=N&amp;ntype=RANKING"><strong>강남·분당·서면…'살인예고' 전국서 하루새 15건</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112011?rc=N&amp;ntype=RANKING"><strong>"늘 다니던 곳도 겁나"…잇단 흉기난동에 커지는 불안감</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112244?rc=N&amp;ntype=RANKING"><strong>포천 버스터미널서 흉기난동?…경찰 "명백한 허위"</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112129?rc=N&amp;ntype=RANKING"><strong>새만금 잼버리 현장 코로나 수십여명 감염…참가자 일부 퇴소</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112156?rc=N&amp;ntype=RANKING"><strong>대통령실 "'尹 신당 창당설' 황당무계…대통령에 멘토는 없어"</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112245?rc=N&amp;ntype=RANKING"><strong>"한미일 정상, 北미사일 방어 협력 논의…정상회의 정례화 공감"</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112162?rc=N&amp;ntype=RANKING"><strong>교육부 "서초구 교사 사망, 학부모민원·업무부담 등 영향 추정"</strong></a>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/001/0014112093?rc=N&amp;ntype=RANKING"><strong>국방부, 故채수근 상병 사건 수사 축소 의혹…"사단장은 빼라"</strong></a>

# %%
import
# Out:
# 200
#
#
#
#
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="referrer" contents="always">
# <meta http-equiv="refresh" content="600" />
# <meta name="viewport" content="width=1106" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="og:title"       content="네이버 뉴스">
# <meta property="og:type"        content="website">
# <meta property="og:url"         content="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y">
# <meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
# <meta property="og:description" content="다양한 기사 정보를 제공합니다.">
# <meta property="og:article:author"	content="네이버"/>
#
# <meta name="twitter:card"		content="summary">
# <meta name="twitter:title"		content="네이버 뉴스">
# <meta name="twitter:site"       content="네이버 뉴스">
# <meta name="twitter:creator"    content="네이버 뉴스">
# <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# <meta name="twitter:description" content="다양한 기사 정보를 제공합니다.">
#
#
#
#
#
#
#
# <title>연합뉴스
# 			 속보 홈 : 네이버 뉴스	</title>
# <link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" />
#
#
#
#
#
#
#
#
#
#
#
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/css/common.css"/>
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/css/news.css"/>
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/js/news.jindo.js" charset="euc-kr"></script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/js/news.jquery.js" charset="utf-8"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.press';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Fri Aug 04 11:38:37 KST 2023";
# </script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/js/news.service.js" charset="euc-kr"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
#
#
# </head>
#
# <body>
# 	<div id="wrap">
# 		<!-- 광고적용 태그 추가 -->
# 		<div id="da_base"></div>
# 		<div id="da_stake"></div>
#
#
#
# <div id="header" class="header">
#
# 	<div id="u_skip">
# 		<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# 		<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# 	</div>
#
#
# 	<div class="snb_area">
# 		<div class="snb_inner">
#
# <div class="gnb_area">
#    <div class="gnb_wrap">
#
#       <div id="gnb" class="gnb_dark_type2"></div>
#
#    </div>
#    <div class="gnb_search is_hidden _search_content">
#    </div>
#    <div id="gnb_search_tool" class="gnb_tool">
#       <a href="javascript:;" class="tool_button _search_content_toggle_btn nclicks(gnb.sch)"><span class="icon_search">검색</span></a>
#    </div>
# </div>
#
#
#
# <div id="snb_wrap">
#     <h1>
#         <a href="https://www.naver.com/" class="h_logo nclicks(gnb.naver)"><span class="blind">NAVER</span></a>
#         <a href="/" class="h_news nclicks(gnb.news)"><span class="blind">뉴스</span></a>
#     </h1>
#     <ul class="snb_related_service">
#         <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="entertain nclicks(gnb.enter)">TV연예</a></li>
#         <li><span class="snb_bdr"></span><a href="https://sports.news.naver.com" class="sports nclicks(gnb.sports)">스포츠</a></li>
#         <li><span class="snb_bdr"></span><a href="https://weather.naver.com" class="weather nclicks(gnb.weather)">날씨</a></li>
#         <li><span class="snb_bdr"></span><a href="https://contents.premium.naver.com" class="premium nclicks(gnb.premium)">프리미엄</a></li>
#     </ul>
# </div>
# 		</div>
# 	</div>
# 	<div class="lnb_area">
# 		<div class="lnb_inner">
#
#
#
#
#
#
#
# <div class="lnb_both">
# 	<div class="lnb_left">
# 		<div id="lnb" class="lnb_menu">
# 			<ul>
# 				<li><a href="/" class="nclicks(lnb.pcmedia)"><span class="tx">언론사별</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lnb.pol)"><span class="tx">정치</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=101" class="nclicks(lnb.eco)"><span class="tx">경제</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=102" class="nclicks(lnb.soc)"><span class="tx">사회</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=103" class="nclicks(lnb.lif)"><span class="tx">생활/문화</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=105" class="nclicks(lnb.sci)"><span class="tx">IT/과학</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=104" class="nclicks(lnb.wor)"><span class="tx">세계</span> </a></li>
# 				<li><a href="/main/ranking/popularDay.naver?mid=etc&sid1=111" class="nclicks(lnb.rankin)"><span class="tx">랭킹</span> </a></li>
# 				<li><a href="/newspaper/home" class="nclicks(lnb.paper)"><span class="tx">신문보기</span> </a></li>
# 				<li><a href="/opinion/home" class="nclicks(lnb.opi)"><span class="tx">오피니언</span> </a></li>
# 				<li><a href="/main/tv/index.naver?mid=tvh" class="nclicks(lnb.tv)"><span class="tx">TV</span> </a></li>
# 				<li><a href="/main/factcheck/main.naver" class="nclicks(lnb.fact)"><span class="tx">팩트체크</span> </a></li>
# 				<li><a href="https://media.naver.com/algorithm" class="nclicks(lnb.algo)"><span class="tx">알고리즘 안내</span> </a></li>
#
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="lnb_right">
# 		<div class="lnb_extra">
#
#
# 			<div class="lnb_extra_menu">
# 				<ul class="lnb_extra_menu_list">
# 					<li class="lnb_extra_menu_item"><a href="https://news.naver.com/main/officeList.naver" class="lnb_extra_menu_link nclicks(nct.right3)" title="전체 언론사">전체 언론사</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newsstand.naver.com/" class="lnb_extra_menu_link nclicks(STA.newsstand)" title="뉴스스탠드" target="_blank">뉴스스탠드</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="lnb_extra_menu_link nclicks(nct.right4)" title="라이브러리" target="_blank">라이브러리</a></li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
#
#
#     <div class="lnb">
#
#
#
#
#         <span class="lnb_date"><strong>08</strong>.<strong>04</strong><span class="day">(금)</span></span>
#
#         <ul class="lnb_side" tabindex="0">
#             <li><a href="https://news.naver.com/main/officeList.naver" class="nclicks(slb.allmedia)" title="전체 언론사">전체 언론사</a></li>
#             <li><a href="https://newsstand.naver.com/" class="nclicks(slb.newsstand)" title="뉴스스탠드" target="_blank" >뉴스스탠드</a></li>
#             <li><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="nclicks(slb.library)" title="라이브러리" target="_blank">라이브러리</a></li>
#         </ul>
#     </div>
#
# </div>
# 		<hr>
#
# 		<table cellpadding="0" cellspacing="0" class="container">
# 			<caption class="blind">기사목록</caption>
# 			<colgroup>
# 				<col class="col_snb">
# 				<col class="col_content">
# 				<col class="col_aside">
# 			</colgroup>
# 			<tr>
# 				<td class="snb">
# 					<div id="snb" class="snb">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <h2 class="h"><a href="/main/list.naver?mode=LSD&mid=sec&sid1=001" class="nclicks(lmn_fla.home)">속보</a></h2>
# <ul class="nav">
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=100" class="snb_s nclicks(lmn_fla.pol)">정치 </a></li>
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=101" class="snb_s2 nclicks(lmn_fla.eco)">경제 </a></li>
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=102" class="snb_s3 nclicks(lmn_fla.soc)">사회 </a></li>
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=103" class="snb_s4 nclicks(lmn_fla.lif)">생활/문화 </a></li>
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=104" class="snb_s5 nclicks(lmn_fla.wor)">세계 </a></li>
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=105" class="snb_s6 nclicks(lmn_fla.sci)">IT/과학 </a></li>
# <li><a href="/main/list.naver?mode=LSD&mid=sec&sid1=110" class="snb_s9 nclicks(lmn_fla.col)">오피니언 </a></li>
# <li class="on"><a href="/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y" class="snb_s10 nclicks(lmn_fla.yon)">연합뉴스 속보 <span class="blind">선택됨</span></a></li>
# </ul>
# <div class="snb_banner">
#  <a href="https://media.naver.com/channel/setting?back=main" class="nclicks(lmn_fla.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71" height="74" alt="언론사 구독하기" /></a>
# </div>
# <div class="snb_banner">
#  <a href="https://contents.premium.naver.com/" class="nclicks(lmn_fla.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71" height="74" alt="네이버 프리미엄콘텐츠" /></a>
# </div>
#
#
#
# 					</div>
# 				</td>
# 				<td class="content">
# 					<div id="main_content" class="content">
# 						<div class="list_header newsflash_header">
# 		<h3>연합뉴스 속보</h3>
# 		<p class="ytn_info"><span class="bar">|</span> 이 페이지는  연합뉴스가 직접 편집합니다.</p>
#
# 	</div>
#
#
#
#
#
# <div class="list_body newsflash_body">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="ytn_top">
#       <dl class="type04">
#
#
#
#
#
#
#
#
#
#
#
#
#               <dt class="photo"><a href="https://n.news.naver.com/mnews/article/001/0014111971?sid=000000"><img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111971.jpg?type=nf175_110"
#                                                                                          width="132" height="90" alt="대전서 고등학교서 면식범 소행 추정 칼부림…경찰 추적 중">
#                 <span class="trans_border"></span></a></dt>
#
#             <dt><a href="https://n.news.naver.com/mnews/article/001/0014111971?rc=N&ntype=RANKING"  class="nclicks(cnt_flashart)">대전서 고등학교서 면식범 소행 추정 칼부림…경찰 추적 중</a></dt>
#             <dd>대전대덕경찰서[연합뉴스TV 제공](대전=연합뉴스) 이주형 기자 = 4일 오전 10시 3분께 대전 대덕구의 한 고등학교에서 20∼30대 ...
#             <div class="emphasis_info _rcount" data-comment="{gno:'news001,0014111971',nclicks:'fls.cmt'}"><span class="writing">연합뉴스</span><span class="date">2023.08.04</span></div>
#
#
#
#             </dd>
#
#
#       </dl>
#     </div>
#
#
#
#
#     <ul class="type02">
#     <li class="_rcount" data-comment="{gno:'news001,0014112029',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014112029?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>[속보] 한총리 &#034;&#039;잼버리 예비비&#039; 즉각 집행해 신속 조치&#034;</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 11:36</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014112011',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014112011?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>&#034;늘 다니던 곳도 겁나&#034;…잇단 흉기난동에 커지는 불안감</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 11:28</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014111658',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014111658?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>관계당국 &#034;분당 흉기 난동 사건 피해자 중 2명 뇌사 가능성&#034;</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 9:37</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014111801',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014111801?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>서울시내 &#039;살인예고&#039; 하루만에 11건…경찰 밤샘 수색</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 10:25</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014111966',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014111966?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>법무부 &#034;&#039;가석방 없는 무기형&#039; 신설 검토…흉악범죄 엄정 대응&#034;</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 11:16</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014112026',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014112026?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>유병언 차남, 횡령액 대부분은 아버지 사진 작품 판매 대금</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 11:35</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014111944',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014111944?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>카눈 일본 관통할 듯…동해까지 &#039;태풍&#039;으로 북상할 수도</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 11:08</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014111941',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014111941?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>尹 지지율 2%p 떨어진 33%…국민의힘 32%, 민주당 31%[한국갤럽]</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 11:08</span>
#     </li>
#
#
#
#
#     <li class="_rcount" data-comment="{gno:'news001,0014111838',nclicks:'fls.cmt'}">
#       <a href="https://n.news.naver.com/mnews/article/001/0014111838?rc=N&ntype=RANKING"class="nclicks(cnt_flashart)"><strong>검찰, &#039;쌍방울 대북 송금 의혹&#039; 정진상 전 실장 비공개 소환</strong></a>
#       <span class="writing">연합뉴스</span>
#
#
#
#
#
#
#       <span class="date">2023.08.04. 오전 10:30</span>
#     </li>
#
#     </ul>
#
#
# </div>
#
#
#
#
#
# 	<div class="paging paging_ytn">
# <strong>1</strong>
# <a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230804&page=2" class="nclicks(fls.page)">2</a>
# <a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230804&page=3" class="nclicks(fls.page)">3</a>
# <a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230804&page=4" class="nclicks(fls.page)">4</a>
# <a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230804&page=5" class="nclicks(fls.page)">5</a>
# <a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230804&page=6" class="nclicks(fls.page)">6</a>
# <a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230804&page=7" class="nclicks(fls.page)">7</a>
# </div>
#
# <h4 class="blind">연합뉴스 이전날짜 더보기 링크모음</h4>
# <div class="pagenavi_day pagenavi_day_ytn">
# <span class="viewday">8월4일(금)</span><span class="devidebar">&middot;</span><a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230803" class="nclicks(fls.date)">8월3일(목)</a><span class="devidebar">&middot;</span><a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230802" class="nclicks(fls.date)">8월2일(수)</a><span class="devidebar">&middot;</span><a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230801" class="nclicks(fls.date)">8월1일(화)</a><span class="devidebar">&middot;</span><a href="?mode=LPOD&sid2=140&sid1=001&mid=sec&oid=001&isYeonhapFlash=Y&date=20230731" class="nclicks(fls.date)">7월31일(월)</a></div>
#
#
#
#
#
# <ul class="ytn_bottom">
#   <ul class="ytn_bottom">
#  <li>
#   <dl class="type05">
#    <dt>
#      화제의 사진/영상
#    </dt>
#    <dd class="type_photo">
#     <ul>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804044800061?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111784.jpg?type=nf175_110" alt="" width="175" height="110" /> '살인예고' 글 올라온 성남 오리역&middot;서현역 주민&middot;상인들 초…<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230803157800061?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/03/14111332.jpg?type=nf175_110" alt="" width="175" height="110" /> &quot;범인 올까 두려웠지만 계속 지혈&quot;…부상자에 달려간 윤도일…<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804049200003?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111858.jpg?type=nf175_110" alt="" width="175" height="110" /> 잼버리 '바가지' 논란에…GS25, 시중가 수준으로 인하<span class="trans_border"></span> </a> </li>
#     </ul>
#    </dd>
#   </dl> </li>
# </ul>
# <ul class="ytn_bottom">
#  <li>
#   <dl class="type05">
#    <dt>
#    </dt>
#    <dd class="type_photo">
#     <ul>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804049700061?input=1195z"> <img src="https://imgnews.pstatic.net/image/upload/item/2023/08/04/110238737_page.jpg" alt="" width="175" height="110" /> &quot;맨날 다니던 집앞서 어찌 어런 일이&quot;…뇌사 피해자 남편 '…<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804053100055?input=1195z"> <img src="https://imgnews.pstatic.net/image/upload/item/2023/08/04/111511432_page.jpg" alt="" width="175" height="110" /> 잼버리 학부모들 &quot;아이들 더위&middot;벌레에 힘들어해…일부는 퇴…<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804052000055?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111881.jpg?type=nf175_110" alt="" width="175" height="110" /> &quot;한국 청소년들 귀하게 자라서&quot; 댓글 단 전북도의원 사과<span class="trans_border"></span> </a> </li>
#     </ul>
#    </dd>
#   </dl> </li>
# </ul>
# <ul class="ytn_bottom">
#  <li>
#   <dl class="type05">
#    <dt>
#      오늘의 사건 / 사고
#    </dt>
#    <dt class="photo">
#     <a href="https://www.yna.co.kr/view/AKR20230804041600053?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111726.jpg?type=nf175_110" alt="" width="175" height="110" /> 경북 포항 하수도관서 가스 누출 화재…근로자 2명, 2도 화상<span class="trans_border"></span></a>
#    </dt>
#    <dd>
#     <ul>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804038100054?input=1195z"> &quot;선풍기 고쳐 달랬더니&quot;…숙박업소 주인 살해한 70대… </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804019700063?input=1195z"> 공주 국도서 자전거 타던 70대, 차량 3대에 잇따라 … </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804043900052?input=1195z"> 임금체불 처벌 피하려 고소 취소장 위조한 하청업체 … </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804030800052?input=1195z"> 창원서 심야에 차도 걷던 80대 차에 치여 숨져 </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804020400065?input=1195z"> 낚시 갔다 실종된 60대, 인천 강화 농수로서 숨진 채… </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#     </ul>
#    </dd>
#   </dl> </li>
# </ul>
# <ul class="ytn_bottom">
#  <li>
#   <dl class="type05">
#    <dt>
#     <a href="https://www.yna.co.kr/view/AKR20230102074700007?input=1195z"> 스포츠 / 연예 </a>
#    </dt>
#    <dd class="type_photo">
#     <ul>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804058000007?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111980.jpg?type=nf175_110" alt="" width="175" height="110" /> 한국 육상 첫 세계선수권 우승 향해…우상혁, 유럽으로 출국<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804052700007?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111892.jpg?type=nf175_110" alt="" width="175" height="110" /> 고진영, 제주삼다수 마스터스 2R 도중 기권…왼쪽 어깨 담 …<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804049600005?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111867.jpg?type=nf175_110" alt="" width="175" height="110" /> 이선균&middot;정유미 주연 '잠' 토론토국제영화제 초청<span class="trans_border"></span> </a> </li>
#     </ul>
#    </dd>
#   </dl> </li>
# </ul>
# <ul class="ytn_bottom">
#  <li>
#   <dl class="type05">
#    <dt>
#     <a class="on visit" href="https://www.yna.co.kr/view/AKR20230722024700003?input=1195z" target="_blank">#트렌드 #핫클릭 #이슈</a>
#    </dt>
#    <dt class="photo">
#     <a href="https://www.yna.co.kr/view/AKR20230804050500003?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/04/14111869.jpg?type=nf175_110" alt="" width="175" height="110" /> 법인차 '연두색번호판' 국토부 행정예고 지연…&quot;9월 시행 노력&quot;<span class="trans_border"></span></a>
#    </dt>
#    <dd>
#     <ul>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804055900052?input=1195z"> '시중 들라는 거냐'…진주시의회, 과도한 의전 매뉴… </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804050600053?input=1195z"> 홍준표 &quot;총선 지면 내일 없다…지겟작대기라도 모아 … </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804050700063?input=1195z"> '핫플레이스' 예산시장 누적 방문객 137만명 돌파 </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804054300097?input=1195z"> 비야디, 중국 내 월간 판매 테슬라와 격차 3배 이상 … </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230804053200009?input=1195z"> 美서 고금리에 MMF로 자금 몰려…역대 최대 </a> <img src="https://ssl.pstatic.net/static.news/image/news/2017/07/12/ico_photo.gif" alt="포토" title="포토" width="13" height="13" class="icon" /> </li>
#     </ul>
#    </dd>
#   </dl> </li>
# </ul>
# <ul class="ytn_bottom">
#  <li>
#   <dl class="type05">
#    <dt>
#      디지털뉴스
#    </dt>
#    <dd class="type_photo">
#     <ul>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230803057500797?input=1195z"> <img src="https://imgnews.pstatic.net/image/upload/item/2023/08/04/080428105_1.jpg" alt="" width="175" height="110" /> [투톺뉴스] 아이 가방에 '녹음기'…교권 침해일까, 아동 보…<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230801084600797?input=1195z"> <img src="https://imgnews.pstatic.net/image/origin/001/2023/08/03/14108841.jpg?type=nf175_110" alt="" width="175" height="110" /> [Why요?] 운전자는 왜 멀미를 안 할까?<span class="trans_border"></span> </a> </li>
#      <li> <a href="https://www.yna.co.kr/view/AKR20230801045700797?input=1195z"> <img src="https://imgnews.pstatic.net/image/upload/item/2023/08/02/091042101_AKR20230801045700797_01_i_P4.jpg" alt="" width="175" height="110" /> [톺뉴스] 돌아온 아이스버킷챌린지…요양병원 건립 '성큼'<span class="trans_border"></span> </a> </li>
#     </ul>
#    </dd>
#   </dl> </li>
# </ul>
#
# </ul>
#
#
# <div class="yonhap_banner">
#  <h3> <a href="https://www.yna.co.kr/" target="_blank"><img src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/161931909_nban01.png" width="145" height="60" alt="연합뉴스" /></a> <a href="http://www.yonhapnewstv.co.kr" target="_blank"><img src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/162012054_nban02.png" width="145" height="60" alt="연합뉴스 TV" /></a> <a href="https://news.einfomax.co.kr/" target="_blank"><img src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/162028043_nban03.png" width="145" height="60" alt="연합인포맥스" /></a> <a href="http://www.worktv.or.kr" target="_blank"><img src="https://imgnews.pstatic.net/image/upload/item/2016/10/20/162057294_nban04.png" width="145" height="60" alt="한국직업방송" /></a> </h3>
# </div>
#
#
#
#
#
#
# <script type="text/javascript">
#   window.onload = function() {
#     var selected_item = jindo.$('_');
#     if (selected_item != null) {
#       selected_item.className = "highlight";
#       news.section.ScrollingManager.scroll('');
#     }
#   }
#   news.section.MainIssueCollectManager.init({
#     mediaOneDomain : 'https://n.news.naver.com'
#   });
#   news.util.CommentListCountManager.view();
# </script>
# 					</div>
# 				</td>
# 				<td class="aside">
# 					<div class="aside">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="section _officeTopRanking1087479">
#     <h4>언론사별 가장 많이 본 뉴스</h4>
#     <button type="button" class="section_info_icon nclicks('rig.renws2i') _rankingInfoButton">안내</button>
#     <div class="section_info_layer _rankingInfoLayer" style="display: none">각 언론사의 가장 많이 본 기사 1건을 제공합니다. <button type="button" class="section_info_layer_close _rankingInfoCloseButton nclicks('rig.renws2x')"><span>닫기</span></button></div>
#     <p class="section_sub_txt">오전 10시~오전 11시까지 집계한 결과입니다.</p>
#
#
#     <ul class="section_list_ranking_press _rankingList" id="_rankingList0" style="display: block">
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/437/0000354034?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/437/2023/08/04/354034.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/437/0000354034?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">오리역 잠실역 서면역 잇단 살인예고…경찰 &#034;작성자 추적 중 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=437"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2023/07/17/logo_437_56_20230717153920.png" width="16" height="16" alt=""></span>JTBC</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/005/0001628572?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/005/2023/08/04/1628572.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/005/0001628572?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">“나라 망신 현실화” 논란의 잼버리…코로나까지 퍼졌다</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=005"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2018/07/18/logo_005_56_20180718152218.png" width="16" height="16" alt=""></span>국민일보</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/009/0005168127?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/009/2023/08/04/5168127.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/009/0005168127?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">“10억에 사셨죠, 1억씩 내세요”…‘억울한 집주인’ 구제 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=009"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2018/07/20/logo_009_56_20180720194820.png" width="16" height="16" alt=""></span>매일경제</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/011/0004222317?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/011/2023/08/03/4222317.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/011/0004222317?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">서현역 칼부림에 피 철철 흐르는 피해자 지혈해준 고교생 &#039; …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=011"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg" width="16" height="16" alt=""></span>서울경제</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/001/0014111879?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/001/2023/08/04/14111879.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/001/0014111879?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">[1보] 대전 대덕구 고등학교서 칼부림…교사 피습</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=001"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2020/08/11/logo_001_56_20200811154916.png" width="16" height="16" alt=""></span>연합뉴스</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#     </ul>
#
#
#
#     <ul class="section_list_ranking_press _rankingList" id="_rankingList5" style="display: none">
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/023/0003779662?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/023/2023/08/04/3779662.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/023/0003779662?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">월급 2배에 ‘워라밸’ 보장… 공사판 뛰어든 2030 여성 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=023"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/04/29/logo_023_56_20200429140429.png" width="16" height="16" alt=""></span>조선일보</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/082/0001225551?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/082/2023/08/04/1225551.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/082/0001225551?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">&#034;분당 흉기 난동 피해자 중 2명 뇌사 가능성&#034;</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=082"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/082/2019/08/22/logo_082_56_20190822111222.png" width="16" height="16" alt=""></span>부산일보</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/028/0002651006?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/028/2023/08/04/2651006.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/028/0002651006?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">서현역 17살 의인, 피해자 지혈하며 끝까지 보호했다</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=028"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2018/08/01/logo_028_56_20180801163801.png" width="16" height="16" alt=""></span>한겨레</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/055/0001078778?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/055/2023/08/04/1078778.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                                 <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/055/0001078778?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">&#034;친구 되고 싶다, 맥주 한 잔&#034;…혼자 사는 여성 집 앞  …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=055"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg" width="16" height="16" alt=""></span>SBS</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/277/0005295421?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/277/2023/08/03/5295421.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/277/0005295421?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">&#034;1인당 1억씩&#034;…공연 스태프에게 보너스 지급한 여가수</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=277"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2018/07/18/logo_277_56_20180718153218.png" width="16" height="16" alt=""></span>아시아경제</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#     </ul>
#
#
#
#     <ul class="section_list_ranking_press _rankingList" id="_rankingList10" style="display: none">
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/008/0004921032?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/008/2023/08/04/4921032.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/008/0004921032?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">신차 80%가 전기차인 노르웨이...&#034;한국은 더 잘할 겁니 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=008"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/008/2018/09/13/logo_008_56_20180913140213.png" width="16" height="16" alt=""></span>머니투데이</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/366/0000921957?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/366/2023/08/04/921957.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/366/0000921957?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">폭염 속 전단지 돌리는 어르신들 “일부러 받아가는 젊은이들 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=366"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/366/2020/12/23/logo_366_56_20201223182636.png" width="16" height="16" alt=""></span>조선비즈</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/032/0003240536?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/032/2023/08/03/3240536.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/032/0003240536?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">19살 바람이가 달라졌어요</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=032"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png" width="16" height="16" alt=""></span>경향신문</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/214/0001290673?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/214/2023/08/03/1290673.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                                 <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                         </a>
#
# ...
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/665/0000001400?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">&#034;끼리끼리 공사&#034; 부실한 무량판에 카르텔 숨어있나 [분석+ …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16" height="16" alt=""></span>더스쿠프</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/145/0000019300?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/145/2023/08/04/19300.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/145/0000019300?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">“차가운 거 먹어서 그렇지…” 병원 가봐야 하는 설사 증상 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16" height="16" alt=""></span>레이디경향</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#     </ul>
#
#
#
#
#
#
#     <button type="button" class="refresh_button nclicks('rig.renws2new') _refreshButton">더보기</button>
#
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087479");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
#
#
#
#                     <div class="side_ad" id="glad_ad_sidebox"></div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="section" style="margin-bottom:20px; white-space:nowrap;" id="right_dailyList">
#     <h4>분야별 주요뉴스</h4>
#     <div class="classfy sd" style="display:block">
#
#
#
#             <ul class="list_txt">
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/009/0005168144?sid=100" class="nclicks(rig.secteco)" title="[속보] 당정 “잼버리에 전기 공급 용량 증설·쿨링 텐트·버스 공급”">[속보] 당정 “잼버리에 전기 공급 용량 증설·쿨링 텐트·버스 공급”</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/016/0002178890?sid=102" class="nclicks(rig.secteco)" title="어느 특수학교 교사의 독백[박정규의 작살]">어느 특수학교 교사의 독백[박정규의 작살]</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/023/0003779641?sid=100" class="nclicks(rig.secteco)" title="‘노인 비하’ 파문에 놀란 野, 이틀간 노인회만 4번 방문">‘노인 비하’ 파문에 놀란 野, 이틀간 노인회만 4번 방문</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/016/0002178913?sid=104" class="nclicks(rig.secteco)" title="영국 기준금리 연 5.25%로 0.25%p 인상…15년 만에 최고">영국 기준금리 연 5.25%로 0.25%p 인상…15년 만에 최고</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/055/0001078747?sid=104" class="nclicks(rig.secteco)" title="폴란드 총리 &quot;바그너 그룹 나토 동부전선 불안정 조장&quot;">폴란드 총리 "바그너 그룹 나토 동부전선 불안정 조장"</a>
#                 </li>
#             </ul>
#
#             <ul class="list_txt">
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/293/0000046595?sid=105" class="nclicks(rig.secteco)" title="아마존, 2분기 호실적에 시간외서 10% 급등">아마존, 2분기 호실적에 시간외서 10% 급등</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/001/0014109243?sid=101" class="nclicks(rig.secteco)" title="현대차그룹, '반도체 설계의 전설' 짐 켈러와 손잡았다(종합)">현대차그룹, '반도체 설계의 전설' 짐 켈러와 손잡았다(종합)</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/469/0000753178?sid=103" class="nclicks(rig.secteco)" title="AI 확진 고양이 보호소 사료서 조류독감 항원 검출.. 농식품부 “추적조사 중”">AI 확진 고양이 보호소 사료서 조류독감 항원 검출.. 농식품부 “추적조사 중”</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/015/0004875858?sid=105" class="nclicks(rig.secteco)" title="LK-99 검증위 &quot;초전도체 특징인 '마이스너 효과'와 달라&quot;">LK-99 검증위 "초전도체 특징인 '마이스너 효과'와 달라"</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/366/0000921960?sid=105" class="nclicks(rig.secteco)" title="‘재계 서열 12위’ KT 이끌 최종 사장 후보 오늘 발표…김영섭·박윤영·차상균 심층면접">‘재계 서열 12위’ KT 이끌 최종 사장 후보 오늘 발표…김영섭·박윤영·차상균 심층면접</a>
#                 </li>
#             </ul>
#
#             <ul class="list_txt">
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/022/0003841254?sid=102" class="nclicks(rig.secteco)" title="선 넘는 폭언·폭력에 시달리는 교사들 … “선생님 수영복 입은 모습 상상돼” 성희롱도">선 넘는 폭언·폭력에 시달리는 교사들 … “선생님 수영복 입은 모습 상상돼” 성희롱도</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/003/0012013441?sid=102" class="nclicks(rig.secteco)" title="강진군, 주택 신축 신규 전입자 3천만원 지원">강진군, 주택 신축 신규 전입자 3천만원 지원</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/016/0002179051?sid=102" class="nclicks(rig.secteco)" title="&quot;더운데 선풍기 안고쳐줘&quot;…숙박업소 주인 살해한 70대">"더운데 선풍기 안고쳐줘"…숙박업소 주인 살해한 70대</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/020/0003513131?sid=102" class="nclicks(rig.secteco)" title="입센 전집 완역 김미혜 교수, 노르웨이 훈장 받아">입센 전집 완역 김미혜 교수, 노르웨이 훈장 받아</a>
#                 </li>
#
#
#
#
#                 <li>
#                     <a href="https://n.news.naver.com/mnews/article/009/0005167966?sid=103" class="nclicks(rig.secteco)" title="뉴진스 '빌보드 200' 1위, K팝 걸그룹 2번째">뉴진스 '빌보드 200' 1위, K팝 걸그룹 2번째</a>
#                 </li>
#             </ul>
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://factcheck.snu.ac.kr/" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2020/02/05/175955946_%2540banner_300X80_pc.png" width="300" alt="온라인 허위정보, 팩트체크 어떻게 확인할까요" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://media.naver.com/algorithm" class="nclicks(rig.banner)"> <img src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" width="300" alt="알고리즘 안내" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195329402_banner_24hours.png" width="300" alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <h4> <a href="https://news.naver.com/main/ombudsman/index.naver" class="nclicks(rig.text)"> 서비스 안내 </a> </h4>
#  <ul class="list_txt">
#   <li> <a href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" class="nclicks(rig.text)"> 고침 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb" class="nclicks(rig.text)"> 정정&middot;반론&middot;추후 보도 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb" class="nclicks(rig.text)"> 불공정 선거 보도 기사 모음 </a> </li>
#  </ul>
#  <a href="https://news.naver.com/main/ombudsman/index.naver" class="more_link nclicks(rig.text)"><span class="blind">서비스 안내</span>더보기</a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
#
# 					</div>
# 				</td>
# 			</tr>
# 		</table>
# 	</div>
#
# 	<hr>
# <div class="index">
#
#
#
# <div class="index_inner">
#
# 	<div class="floating_btn" >
# 		<div class="floating_inner">
# 			<a href="javascript:history.back();" class="floating_btn_back"><span class="blind">이젠 페이지</span></a>
# 			<a href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;" class="floating_btn_top"><span class="blind">맨위로</span></a>
# 		</div>
# 	</div>
# 	<div id="index.press_category" class="index_tab">
# 		<a id="index.press.btn" href="#" class="spr stit nclicks(fot.press)">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.press.area" class="index_content is_hidden"></div>
# 		<a id="index.category.btn" href="#" class="spr stit2 nclicks(fot.section)">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.category.area" class="index_content02 is_hidden"></div>
# 	</div>
# </div>
#
#
# </div>
# <hr>
# <div id="footer">
#
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" class="nclicks(fot.agreement)">이용약관</a></li>
# <li><a href="/main/ombudsman/index.naver" class="nclicks(fot.guide)">서비스 안내</a></li>
# <li><a href="/main/ombudsman/edit.naver?mid=omb" class="nclicks(fot.editor)">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a href="http://www.naver.com/rules/privacy.html" class="nclicks(fot.privacy)">개인정보처리방침</a></strong></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" class="nclicks(fot.disclaimer)">책임의 한계와 법적고지</a></li>
# <li><a href="#" title="새창" onclick="news.external.OPS.helpNews(); return false;" class="nclicks(fot.help)">뉴스 고객센터</a></li>
# </ul>
# 	<p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
#
#
# 	<address class="address_nhn">
# 	<a href="https://www.navercorp.com/" target="_blank" class="logo nclicks(fot.naver)"><span class="blind">NAVER</span></a>
# 	<em>Copyright &copy;</em>
# 	<a href="https://www.navercorp.com/" target="_blank" class="nclicks(fot.navercorp)">NAVER Corp.</a>
# 	<span>All Rights Reserved.</span>
# </address>
# 	<!-- -->
#
#
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
## 벅스뮤직 차트 크롤링
import requests
from bs4 import BeautifulSoup

def crawler(soup):
    # print(soup) # 여기까지 전달 잘됨
    div = soup.find("div", class_ = "CHARTrealtime")

    result = []
    for a in div.find_all("th"): # find_all 반환값 형태는 리스트다! 
        result.append(th.get_text())
    
    
    return result

def main():

    # 요청 url 변수에 담긴 url의 html 문서를 출력한다. 
    custom_header = {
        'referer' : 'https://music.bugs.co.kr/chart'
        
    }
    
    url = "https://music.bugs.co.kr/chart"
    req = requests.get(url, headers = custom_header)
    soup = BeautifulSoup(req.text, "html.parser")
    result = crawler(soup)
    print(result)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 31
#      28     print(result)
#      30 if __name__ == "__main__":
# ---> 31     main()
#
# Cell In[15], line 27, in main()
#      25 req = requests.get(url, headers = custom_header)
#      26 soup = BeautifulSoup(req.text, "html.parser")
# ---> 27 result = crawler(soup)
#      28 print(result)
#
# Cell In[15], line 10, in crawler(soup)
#       7 div = soup.find("div", class_ = "CHARTrealtime")
#       9 result = []
# ---> 10 for a in div.find_all("th"): # find_all 반환값 형태는 리스트다!
#      11     result.append(th.get_text())
#      14 return result
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# !pip install fake_useragent
# Out:
# Collecting fake_useragent
#   Obtaining dependency information for fake_useragent from https://files.pythonhosted.org/packages/d0/4b/1479877468e20c9a5719336a52bb0ee6f822d387b67f05a0c81e098064cc/fake_useragent-1.2.1-py3-none-any.whl.metadata
#   Downloading fake_useragent-1.2.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\choi so hyeon\desktop\multicampus28\venv\lib\site-packages (from fake_useragent) (6.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\choi so hyeon\desktop\multicampus28\venv\lib\site-packages (from importlib-resources>=5.0->fake_useragent) (3.16.2)
# Downloading fake_useragent-1.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: fake_useragent
# Successfully installed fake_useragent-1.2.1

# %%
## 벅스뮤직

# %%
# 벅스 뮤직 1~100 제목 가져오기
import requests
from bs4 import BeautifulSoup
import pandas as pd

def creadDF(result_list):
    result_df = pd.DataFrame({"title" : result_list})

    return result_df

def crawler(soup):
    # print(soup) # 여기까지 전달 잘됨
    
    tbody = soup.find("tbody")
    result = []
    for p in tbody.find_all("p", class_ = "title"): # find_all 반환값 형태는 리스트다! 
        result.append(p.get_text().replace('\n', ''))

    return result

def main():

    # 요청 url 변수에 담긴 url의 html 문서를 출력한다. 
    custom_header = {
        'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    }
    
    url = "https://music.bugs.co.kr/chart"
    req = requests.get(url, headers = custom_header)
    soup = BeautifulSoup(req.text, "html.parser")
    result = crawler(soup)
    df = creadDF(result)
    print(df)
    df.to_csv("result.csv", index=False)

if __name__ == "__main__":
    main()
# Out:
#                                title
# 0                                ETA
# 1                          Super Shy
# 2   Seven (feat. Latto) - Clean Ver.
# 3                          New Jeans
# 4                               I AM
# ..                               ...
# 95                       사막에서 꽃을 피우듯
# 96                              CAKE
# 97                           부동의 첫사랑
# 98                               드라마
# 99                         CHRISTIAN
#
# [100 rows x 1 columns]

# %%
# 벅스 뮤직 1~100 제목 가져오기
import requests
from bs4 import BeautifulSoup
import pandas as pd

def creadDF(result_list):
    result_df = pd.DataFrame({"title" : result_list})

    return result_df

def crawler(soup):
    # print(soup) # 여기까지 전달 잘됨
    
    tbody = soup.find("tbody")
    result = []
    for p in tbody.find_all("p", class_ = "title"): # find_all 반환값 형태는 리스트다! 
        result.append(p.get_text().replace('\n', ''))

    return result

def main():

    # 요청 url 변수에 담긴 url의 html 문서를 출력한다. 
    custom_header = {
        'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    }
    
    url = "https://music.bugs.co.kr/chart"
    req = requests.get(url, headers = custom_header)
    soup = BeautifulSoup(req.text, "html.parser")
    result = crawler(soup)
    df = creadDF(result)
    print(df)
    df.to_csv("result.csv", index=False)

if __name__ == "__main__":
    main()
# Out:
#                                title
# 0                                ETA
# 1                          Super Shy
# 2   Seven (feat. Latto) - Clean Ver.
# 3                          New Jeans
# 4                               I AM
# ..                               ...
# 95                       사막에서 꽃을 피우듯
# 96                              CAKE
# 97                           부동의 첫사랑
# 98                               드라마
# 99                         CHRISTIAN
#
# [100 rows x 1 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
from fake_useragent import UserAgent

# 이 코드를 어떻게 활용할 것인가? 
def getSoup(com_code):
    url = 'https://finance.naver.com/item/main.naver?code=' + com_code
    ua = UserAgent()
    
    # 기존 user-agent와 원리는 같음. 다만, 이런 라이브러리가 존재한다! 정도로만 확인해주세요!
    headers = {'user-agent' : ua.ie} 
    req = requests.get(url)
    soup = BeautifulSoup(req.text, "html.parser")
    return soup 

def getPrice(com_code):
    soup = getSoup(com_code)
    no_today = soup.select_one("p.no_today") # print(no_today)
    price = no_today.select_one("span.blind").get_text()

    return price

def main():
    com_codes = ["030200", "005930", "035720"]
    com_names = ["KT", "삼성전자", "카카오"]

    prices = []
    for code in com_codes:
        price = getPrice(code)
        prices.append(price)
    
    df = pd.DataFrame({"종목코드":com_codes, "상장회사":com_names, "주가":prices})
    print(df)
    df['날짜'] = "오늘날짜"
    print(df)
        
if __name__ == "__main__":
    main()
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# Error occurred during getting browser: ie, but was suppressed with fallback.
# Error occurred during getting browser: ie, but was suppressed with fallback.
#      종목코드  상장회사      주가
# 0  030200    KT  30,750
# 1  005930  삼성전자  68,300
# 2  035720   카카오  51,800
#      종목코드  상장회사      주가    날짜
# 0  030200    KT  30,750  오늘날짜
# 1  005930  삼성전자  68,300  오늘날짜
# 2  035720   카카오  51,800  오늘날짜

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\choi so hyeon\desktop\multicampus28\venv\lib\site-packages (4.9.3)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

def crawler(url, com_code):
  url = url + com_code
  ua = UserAgent()
  headers = { 'user-agent': ua.ie }
  response = requests.get(url, headers=headers)
  soup = BeautifulSoup(response.content, "html.parser")
  return url, soup
def getLastPage(soup):
  # 여기가 핵심 포인트
  last_page = int(soup.select_one('td.pgRR').a['href'].split('=')[-1])
  return last_page
def getData(url, com_code, soup, page):
    df = None
    count = 0
    for page in range(1, page + 1):
      headers = { 'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36' }
      req = requests.get(f'{url}&page={page}', headers=headers)
      # 테이블이 있는  html은 매우 다행스럽게도 매우 쉽게 접근이 가능하다.
      # read_html 메서드를 활용한다.
      df = pd.concat([df, pd.read_html(req.text, encoding = "euc-kr")[0]], ignore_index=True)
      if count > 10:
        break
      count += 1
    data = df.dropna().reset_index(drop=True)
    return data
def main():
    url = "https://finance.naver.com/item/sise_day.nhn?code="
    com_code = '005930' # 삼성전자 다른 종목을 이용할 때 활용
    com_url, soup = crawler(url, com_code)
    last_page = getLastPage(soup)
    result = getData(com_url, com_code, soup, last_page)
    print(result)
if __name__ == "__main__":
    main()
# Out:
# Error occurred during getting browser: ie, but was suppressed with fallback.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 39
#      37     print(result)
#      38 if __name__ == "__main__":
# ---> 39     main()
#
# Cell In[40], line 36, in main()
#      34 com_url, soup = crawler(url, com_code)
#      35 last_page = getLastPage(soup)
# ---> 36 result = getData(com_url, com_code, soup, last_page)
#      37 print(result)
#
# Cell In[40], line 25, in getData(url, com_code, soup, page)
#      22 req = requests.get(f'{url}&page={page}', headers=headers)
#      23 # 테이블이 있는  html은 매우 다행스럽게도 매우 쉽게 접근이 가능하다.
#      24 # read_html 메서드를 활용한다.
# ---> 25 df = pd.concat([df, pd.read_html(req.text, encoding = "euc-kr")[0]], ignore_index=True)
#      26 if count > 10:
#      27   break
#
# File ~\Desktop\multicampus28\venv\lib\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
#    1222     encoding=encoding,
#    1223     decimal=decimal,
#    1224     converters=converters,
#    1225     na_values=na_values,
#    1226     keep_default_na=keep_default_na,
#    1227     displayed_only=displayed_only,
#    1228     extract_links=extract_links,
#    1229     dtype_backend=dtype_backend,
#    1230 )
#
# File ~\Desktop\multicampus28\venv\lib\site-packages\pandas\io\html.py:977, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     975 retained = None
#     976 for flav in flavor:
# --> 977     parser = _parser_dispatch(flav)
#     978     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     980     try:
#
# File ~\Desktop\multicampus28\venv\lib\site-packages\pandas\io\html.py:934, in _parser_dispatch(flavor)
#     932 else:
#     933     if not _HAS_LXML:
# --> 934         raise ImportError("lxml not found, please install it")
#     935 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it
