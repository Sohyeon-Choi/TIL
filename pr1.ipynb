# %%
import numpy as np
import pandas as pd

# %%
In [3]: s = pd.Series([1, 3, 5, np.nan, 6, 8])

In [4]: s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
In [5]: dates = pd.date_range("20130101", periods=6)

In [6]: dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
In [7]: df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

In [8]: df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.648503  0.288428 -0.833608  0.357627
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856
# 2013-01-04 -0.661925  0.624699  1.247226  0.823427
# 2013-01-05  1.358085 -1.445657 -0.395960  1.341568
# 2013-01-06 -0.058114 -1.077509 -0.732579  0.913052

# %%
In [9]: df2 = pd.DataFrame(
            {
                "A": 1.0,
                "B": pd.Timestamp("20130102"),
                "C": pd.Series(1, index=list(range(4)), dtype ="float32"),
                "D": np.array([3] * 4, dtype="int32"),
                "E": pd.Categorical(["test", "train", "test", "train"]),
                "F": "foo"
                }
)

In [10]: df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
In [11]: df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
In [12]: df2.<TAB>  # noqa: E225, E999
# Out:
#   File "<ipython-input-127-2e62111f8e28>", line 1
#     df2.<TAB>  # noqa: E225, E999
#         ^
# SyntaxError: invalid syntax

# %%
In [13]: df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.648503  0.288428 -0.833608  0.357627
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856
# 2013-01-04 -0.661925  0.624699  1.247226  0.823427
# 2013-01-05  1.358085 -1.445657 -0.395960  1.341568

# %%
In [14]: df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.661925  0.624699  1.247226  0.823427
# 2013-01-05  1.358085 -1.445657 -0.395960  1.341568
# 2013-01-06 -0.058114 -1.077509 -0.732579  0.913052

# %%
In [15]: df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
In [16]: df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
In [17]: df.to_numpy()
# Out:
# array([[-0.6485025 ,  0.2884283 , -0.83360823,  0.35762702],
#        [ 0.48092211, -0.65662726, -1.12978988,  2.07505362],
#        [-0.28945164,  0.76337013, -0.2336712 ,  0.83085565],
#        [-0.66192461,  0.62469862,  1.24722551,  0.82342689],
#        [ 1.35808532, -1.44565663, -0.39595952,  1.34156848],
#        [-0.05811434, -1.07750916, -0.73257886,  0.91305211]])

# %%
In [18]: df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
In [19]: df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.030169 -0.250549 -0.346397  1.056931
# std    0.776670  0.933984  0.843210  0.588720
# min   -0.661925 -1.445657 -1.129790  0.357627
# 25%   -0.558740 -0.972289 -0.808351  0.825284
# 50%   -0.173783 -0.184099 -0.564269  0.871954
# 75%    0.346163  0.540631 -0.274243  1.234439
# max    1.358085  0.763370  1.247226  2.075054

# %%
In [20]: df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.648503    0.480922   -0.289452   -0.661925    1.358085   -0.058114
# B    0.288428   -0.656627    0.763370    0.624699   -1.445657   -1.077509
# C   -0.833608   -1.129790   -0.233671    1.247226   -0.395960   -0.732579
# D    0.357627    2.075054    0.830856    0.823427    1.341568    0.913052

# %%
In [21]: df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.357627 -0.833608  0.288428 -0.648503
# 2013-01-02  2.075054 -1.129790 -0.656627  0.480922
# 2013-01-03  0.830856 -0.233671  0.763370 -0.289452
# 2013-01-04  0.823427  1.247226  0.624699 -0.661925
# 2013-01-05  1.341568 -0.395960 -1.445657  1.358085
# 2013-01-06  0.913052 -0.732579 -1.077509 -0.058114

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-05  1.358085 -1.445657 -0.395960  1.341568
# 2013-01-06 -0.058114 -1.077509 -0.732579  0.913052
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054
# 2013-01-01 -0.648503  0.288428 -0.833608  0.357627
# 2013-01-04 -0.661925  0.624699  1.247226  0.823427
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856

# %%
In [23]: df["A"]
# Out:
# 2013-01-01   -0.648503
# 2013-01-02    0.480922
# 2013-01-03   -0.289452
# 2013-01-04   -0.661925
# 2013-01-05    1.358085
# 2013-01-06   -0.058114
# Freq: D, Name: A, dtype: float64

# %%
In [24]: df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.648503  0.288428 -0.833608  0.357627
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856

# %%
In [25]: df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856
# 2013-01-04 -0.661925  0.624699  1.247226  0.823427

# %%
In [26]: df.loc[dates[0]]

# %%
In [27]: df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -0.648503  0.288428
# 2013-01-02  0.480922 -0.656627
# 2013-01-03 -0.289452  0.763370
# 2013-01-04 -0.661925  0.624699
# 2013-01-05  1.358085 -1.445657
# 2013-01-06 -0.058114 -1.077509

# %%
In [28]: df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  0.480922 -0.656627
# 2013-01-03 -0.289452  0.763370
# 2013-01-04 -0.661925  0.624699

# %%
In [29]: df.loc["20130102", ["A", "B"]]
# Out:
# A    0.480922
# B   -0.656627
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
In [30]: df.loc[dates[0], "A"]
# Out:
# -0.6485025019236891

# %%
In [31]: df.at[dates[0], "A"]

# %%
In [32]: df.iloc[3]
# Out:
# A   -0.661925
# B    0.624699
# C    1.247226
# D    0.823427
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
In [33]: df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.661925  0.624699
# 2013-01-05  1.358085 -1.445657

# %%
In [34]: df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  0.480922 -1.129790
# 2013-01-03 -0.289452 -0.233671
# 2013-01-05  1.358085 -0.395960

# %%
In [35]: df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856

# %%
In [36]: df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.288428 -0.833608
# 2013-01-02 -0.656627 -1.129790
# 2013-01-03  0.763370 -0.233671
# 2013-01-04  0.624699  1.247226
# 2013-01-05 -1.445657 -0.395960
# 2013-01-06 -1.077509 -0.732579

# %%
In [37]: df.iloc[1, 1]
# Out:
# -0.6566272644793527

# %%
In [38]: df.iat[1, 1]
# Out:
# -0.6566272644793527

# %%
In [39]: df[df["A"] > 0]
# Out:
#                    A         B        C         D
# 2013-01-02  0.480922 -0.656627 -1.12979  2.075054
# 2013-01-05  1.358085 -1.445657 -0.39596  1.341568

# %%
In [40]: df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.288428       NaN  0.357627
# 2013-01-02  0.480922       NaN       NaN  2.075054
# 2013-01-03       NaN  0.763370       NaN  0.830856
# 2013-01-04       NaN  0.624699  1.247226  0.823427
# 2013-01-05  1.358085       NaN       NaN  1.341568
# 2013-01-06       NaN       NaN       NaN  0.913052

# %%
In [41]: df2 = df.copy()

In [42]: df2["E"] = ["one", "one", "two", "three", "four", "three"]

In [43]: df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.648503  0.288428 -0.833608  0.357627    one
# 2013-01-02  0.480922 -0.656627 -1.129790  2.075054    one
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856    two
# 2013-01-04 -0.661925  0.624699  1.247226  0.823427  three
# 2013-01-05  1.358085 -1.445657 -0.395960  1.341568   four
# 2013-01-06 -0.058114 -1.077509 -0.732579  0.913052  three

# %%
In [44]: df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.289452  0.763370 -0.233671  0.830856   two
# 2013-01-05  1.358085 -1.445657 -0.395960  1.341568  four

# %%
In [45]: s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

In [46]: s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
In [47]: df["F"] = s1

# %%
In [48]: df.at[dates[0], "A"] = 0

# %%
In [49]: df.iat[0, 1] = 0

# %%
In [50]: df.loc[:, "D"] = np.array([5] * len(df))
# Out:
# <ipython-input-149-c9cfd4f62edf>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "D"] = np.array([5] * len(df))

# %%
In [51]: df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.833608  5  NaN
# 2013-01-02  0.480922 -0.656627 -1.129790  5  1.0
# 2013-01-03 -0.289452  0.763370 -0.233671  5  2.0
# 2013-01-04 -0.661925  0.624699  1.247226  5  3.0
# 2013-01-05  1.358085 -1.445657 -0.395960  5  4.0
# 2013-01-06 -0.058114 -1.077509 -0.732579  5  5.0

# %%
In [52]: df2 = df.copy()

In [53]: df2[df2 > 0] = -df2

In [54]: df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.833608 -5  NaN
# 2013-01-02 -0.480922 -0.656627 -1.129790 -5 -1.0
# 2013-01-03 -0.289452 -0.763370 -0.233671 -5 -2.0
# 2013-01-04 -0.661925 -0.624699 -1.247226 -5 -3.0
# 2013-01-05 -1.358085 -1.445657 -0.395960 -5 -4.0
# 2013-01-06 -0.058114 -1.077509 -0.732579 -5 -5.0

# %% [markdown]
# ## Missing data

# %%
In [55]: df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

In [56]: df1.loc[dates[0] : dates[1], "E"] = 1

In [57]: df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.833608  5  NaN  1.0
# 2013-01-02  0.480922 -0.656627 -1.129790  5  1.0  1.0
# 2013-01-03 -0.289452  0.763370 -0.233671  5  2.0  NaN
# 2013-01-04 -0.661925  0.624699  1.247226  5  3.0  NaN

# %%
In [58]: df1.dropna(how="any")
# Out:
#                    A         B        C  D    F    E
# 2013-01-02  0.480922 -0.656627 -1.12979  5  1.0  1.0

# %%
In [59]: df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.833608  5  5.0  1.0
# 2013-01-02  0.480922 -0.656627 -1.129790  5  1.0  1.0
# 2013-01-03 -0.289452  0.763370 -0.233671  5  2.0  5.0
# 2013-01-04 -0.661925  0.624699  1.247226  5  3.0  5.0

# %%
In [60]: pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations

# %% [markdown]
# ## Stats

# %%
In [61]: df.mean()
# Out:
# A    0.138253
# B   -0.298621
# C   -0.346397
# D    5.000000
# F    3.000000
# dtype: float64

# %%
In [62]: df.mean(1)
# Out:
# 2013-01-01    1.041598
# 2013-01-02    0.938901
# 2013-01-03    1.448049
# 2013-01-04    1.842000
# 2013-01-05    1.703294
# 2013-01-06    1.626360
# Freq: D, dtype: float64

# %%
In [63]: s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

In [64]: s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
In [65]: df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.289452 -0.236630 -1.233671  4.0  1.0
# 2013-01-04 -3.661925 -2.375301 -1.752774  2.0  0.0
# 2013-01-05 -3.641915 -6.445657 -5.395960  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ## Apply

# %%
In [66]: df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.833608   5   NaN
# 2013-01-02  0.480922 -0.656627 -1.963398  10   1.0
# 2013-01-03  0.191470  0.106743 -2.197069  15   3.0
# 2013-01-04 -0.470454  0.731441 -0.949844  20   6.0
# 2013-01-05  0.887631 -0.714215 -1.345803  25  10.0
# 2013-01-06  0.829517 -1.791724 -2.078382  30  15.0

# %%
In [67]: df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.020010
# B    2.209027
# C    2.377015
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ## Hisrogramming

# %%
In [68]: s = pd.Series(np.random.randint(0, 7, size=10))

In [69]: s
# Out:
# 0    0
# 1    4
# 2    3
# 3    5
# 4    6
# 5    6
# 6    2
# 7    2
# 8    1
# 9    6
# dtype: int64

# %%
In [70]: s.value_counts()
# Out:
# 6    3
# 2    2
# 0    1
# 4    1
# 3    1
# 5    1
# 1    1
# dtype: int64

# %% [markdown]
# ## String Methods

# %%
In [71]: s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

In [72]: s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge
